# %% [markdown]
# # Reading in Files

# %%
import pandas as pd

# %% [markdown]
# ### Reading in Excel Files

# %%
#When using pandas, it calls files in as dataframes
#I used a pathname I manually copied from my files
#remember to always put 'r' before the pathname
#note in the output, the index [0,1,2,3] is automatically created
#always read a file into a variable
#by default the first worksheet is read in only
#You have to specify which specific sheet you want to read in, see last part after the pathname
df = pd.read_excel(r"/Users/dorianeumuhoza/Library/Mobile Documents/com~apple~CloudDocs/1. My Documents/5. Learning/5.DataAnalysisAlexTheAnalyst/Projects/Reading in Filles Pandas_ Files/Tableau Full Project.xlsx", sheet_name = 'Reviews')

df
# Out:
#        listing_id        id       date  reviewer_id reviewer_name  \
# 0         7202016  38917982 2015-07-19     28943674        Bianca
# 1         7202016  39087409 2015-07-20     32440555         Frank
# 2         7202016  39820030 2015-07-26     37722850           Ian
# 3         7202016  40813543 2015-08-02     33671805        George
# 4         7202016  41986501 2015-08-10     34959538          Ming
# ...           ...       ...        ...          ...           ...
# 84844     3624990  50436321 2015-10-12     37419458          Ryan
# 84845     3624990  51024875 2015-10-17      6933252         Linda
# 84846     3624990  51511988 2015-10-20     19543701         Jaime
# 84847     3624990  52814482 2015-11-02     24445024       JÃ¸rgen
# 84848     9727246  56429621 2015-12-13     30860360     Stephanie
#
#                                                 comments
# 0      Cute and cozy place. Perfect location to every...
# 1      Kelly has a great room in a very central locat...
# ...

# %%
# Out:
#             id                            listing_url       scrape_id  \
# 0       241032    https://www.airbnb.com/rooms/241032  20160104002432
# 1       953595    https://www.airbnb.com/rooms/953595  20160104002432
# 2      3308979   https://www.airbnb.com/rooms/3308979  20160104002432
# 3      7421966   https://www.airbnb.com/rooms/7421966  20160104002432
# 4       278830    https://www.airbnb.com/rooms/278830  20160104002432
# ...        ...                                    ...             ...
# 3813   8101950   https://www.airbnb.com/rooms/8101950  20160104002432
# 3814   8902327   https://www.airbnb.com/rooms/8902327  20160104002432
# 3815  10267360  https://www.airbnb.com/rooms/10267360  20160104002432
# 3816   9604740   https://www.airbnb.com/rooms/9604740  20160104002432
# 3817  10208623  https://www.airbnb.com/rooms/10208623  20160104002432
#
#      last_scraped                                 name  \
# 0      2016-01-04         Stylish Queen Anne Apartment
# ...

# %% [markdown]
# ### Reading in csv or txt Files

# %%
#If I wanted to read in a csv or text file
#It is a faux pathname for display purposes only
#The purpose of the  {sep = '\t' \} breaks up the data into their own columns

df = pd.read_csv(r"C:/Users\counrtries of the world.txt", sep = '\t')

#........OR.....

df = pd.read_table(r"C:/Users\counrtries of the world.csv", sep = ',')

# %% [markdown]
# ### Reading in Json Files

# %%
#Json files hold semi structured data
#also random pathname

# %%
df = pd.read_json(r"C:/Users\counrtries of the world.json")

# %%
#If you want to see all the rows outputted
#I did not run the below but it can be used for the table shown above

#To see all rows

pd.set_option('display.max.rows',3918)

#To see all columns
#eg. 40
pd.set_option('display.max.columns',40)

# %%
#Inspecting data: breakdowns

#remember all of this code is not run, just here for me to give you examples


df1.info()


#tells us number of rows and columns
df1.shape


#give us the first 5 rows(can specify amount)
df1.head()

#give us the last 5 rows(can specify amount)
df1.tail()
